# %%
# %run script/laboratorio1.py
# Out:
# #### Aproximaciones de Bessel
# #### Bessel_ord_2
# $\displaystyle \frac{  3 }{s^2 + s \,\,   3 +   3 }$
# $\displaystyle   \frac{  1 \cdot 1.732^2}{s^2 + s \frac{1.732}{0.5774} + 1.732^2}$
# #### Bessel_ord_3
# $\displaystyle \frac{ 15 }{s^3 + s^2 \,\,   6 + s \,\,  15 +  15 }$
# $\displaystyle   \frac{2.322 }{s + 2.322 } . \frac{  1 \cdot 2.542^2}{s^2 + s \frac{2.542}{0.691} + 2.542^2}$
# #### Bessel_ord_4
# $\displaystyle \frac{105 }{s^4 + s^3 \,\,  10 + s^2 \,\,  45 + s \,\, 105 + 105 }$
# $\displaystyle   \frac{  1 \cdot 3.023^2}{s^2 + s \frac{3.023}{0.5219} + 3.023^2} . \frac{  1 \cdot 3.389^2}{s^2 + s \frac{3.389}{0.8055} + 3.389^2}$
# ...
# Bessel_ord_2
# Ω(3 kHz)       = 1.8850
# τg_norm(0.6π)  = 0.6092
# τg(3 kHz)      = 60.92 μs
# Desvío         = 39.08 %
# >>> NO CUMPLE <<<
#
# ...
# Bessel_ord_3
# Ω(3 kHz)       = 1.8850
# τg_norm(0.6π)  = 0.9114
# τg(3 kHz)      = 91.14 μs
# Desvío         = 8.86 %
# >>> NO CUMPLE <<<
#
# ...
# Bessel_ord_4
# Ω(3 kHz)       = 1.8850
# ...
