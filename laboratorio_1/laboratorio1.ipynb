# %%
# %run script/laboratorio1.py
# Out:
# #### Aproximaciones de Bessel
# #### Bessel_ord_2
# $\displaystyle \frac{3e+08 }{s^2 + s \,\, 3e+04 + 3e+08 }$
# $\displaystyle   \frac{  1 \cdot 1.732e+04^2}{s^2 + s \frac{1.732e+04}{0.5774} + 1.732e+04^2}$
# #### Bessel_ord_3
# $\displaystyle \frac{1.5e+13 }{s^3 + s^2 \,\, 6e+04 + s \,\, 1.5e+09 + 1.5e+13 }$
# $\displaystyle   \frac{2.322e+04 }{s + 2.322e+04 } . \frac{  1 \cdot 2.542e+04^2}{s^2 + s \frac{2.542e+04}{0.691} + 2.542e+04^2}$
# #### Bessel_ord_4
# $\displaystyle \frac{1.05e+18 }{s^4 + s^3 \,\, 1e+05 + s^2 \,\, 4.5e+09 + s \,\, 1.05e+14 + 1.05e+18 }$
# $\displaystyle   \frac{1.05e+18 \cdot s^2}{s^2 + s \frac{3.389e+04}{0.8055} + 3.389e+04^2} . \frac{  1 \cdot s^2}{s^2 + s \frac{3.023e+04}{0.5219} + 3.023e+04^2}$
# #### Bessel_ord_5
# $\displaystyle \frac{9.45e+22 }{s^5 + s^4 \,\, 1.5e+05 + s^3 \,\, 1.05e+10 + s^2 \,\, 4.2e+14 + s \,\, 9.45e+18 + 9.45e+22 }$
# ...
