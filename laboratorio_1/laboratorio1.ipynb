# %%
# %run script/laboratorio1.py
# Out:
# #### Aproximaciones de Bessel
# #### Bessel_ord_2
# $\displaystyle \frac{0.304 }{s^2 + s \,\, 0.9549 + 0.304 }$
# $\displaystyle   \frac{  1 \cdot 0.5513^2}{s^2 + s \frac{0.5513}{0.5774} + 0.5513^2}$
# #### Bessel_ord_3
# $\displaystyle \frac{0.4838 }{s^3 + s^2 \,\, 1.91 + s \,\, 1.52 + 0.4838 }$
# $\displaystyle   \frac{0.7392 }{s + 0.7392 } . \frac{  1 \cdot 0.809^2}{s^2 + s \frac{0.809}{0.691} + 0.809^2}$
# #### Bessel_ord_4
# $\displaystyle \frac{1.078 }{s^4 + s^3 \,\, 3.183 + s^2 \,\, 4.559 + s \,\, 3.386 + 1.078 }$
# $\displaystyle   \frac{0.9999 \cdot 0.9623^2}{s^2 + s \frac{0.9623}{0.5219} + 0.9623^2} . \frac{  1 \cdot 1.079^2}{s^2 + s \frac{1.079}{0.8055} + 1.079^2}$
# #### Bessel_ord_5
# $\displaystyle \frac{3.088 }{s^5 + s^4 \,\, 4.775 + s^3 \,\, 10.64 + s^2 \,\, 13.55 + s \,\, 9.701 + 3.088 }$
# $\displaystyle   \frac{1.161 }{s + 1.161 } . \frac{  1 \cdot 1.203^2}{s^2 + s \frac{1.203}{0.5635} + 1.203^2} . \frac{  1 \cdot 1.356^2}{s^2 + s \frac{1.356}{0.9165} + 1.356^2}$
# ...
