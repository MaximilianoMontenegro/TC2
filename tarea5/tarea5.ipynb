# %%
from IPython.display import IFrame

IFrame("Manuscrito/Tarea 5_260706_222712.pdf",width=900,height=700)
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="Manuscrito/Tarea 5_260706_222712.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
