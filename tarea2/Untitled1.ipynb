# %% [markdown]
# # Tarea 2 - Filttro pasabajos - chevischev -- Montenegro, Maximiliano

# %% [markdown]
# ## 1 - Transferencia del filtro pasabajos T(S), con parametros $\omega_{0}$, Q, K

# %% [markdown]
# $$ T(S) = \frac{-1}{R_{1}R_{3}C^2} \frac{1}{S^2 + S\frac{1}{R_{2}C}+(\frac{1}{R_{3}C})^2} $$

# %% [markdown]
# siendo: $$\omega_{0} = \frac{1}{R_{3}C}$$ $$Q = \frac{R_{2}}{R_{3}}$$ $$K=-\frac{R_{3}}{R_{2}}$$

# %% [markdown]
# normalizado: $$T(S) = -\frac{R_{3}}{R_{2}} \frac{1}{S^2 + S\frac{1}{Q}+1}$$

# %% [markdown]
# ## 2 - Transferencia del filtro pasabandas $$T(S) = -\frac{1}{R_{3}C} \frac{S}{S^2 + S\frac{1}{R_{2}C} + (\frac{1}{R_{3}C})^2} $$

# %% [markdown]
# siendo: $$\omega_{0} = \frac{1}{R_{3}C}$$ $$Q = \frac{R_{2}}{R_{3}}$$ $$K=-\frac{1}{R_{3}C}$$

# %% [markdown]
# ## Filtro Chevischev de orden n = 5

# %% [markdown]
# ## $$C_{0} = 1 $$ $$C_{1} = \omega$$ $$C_{n} = 2 \omega C_{n-1}(\omega)-C_{n-2}(\omega)$$

# %% [markdown]
# ## Para n = 5
# $$C_{5} = 16\omega ^5 -20 \omega ^3 + 5 \omega $$

# %% [markdown]
# ## T(S) para orden 5:
# $$T(S) = \frac{1}{16 \epsilon} \frac {1}{S^5 + S^4 3,256 + S^3 5,236 + S^2 5,236 + S 3,2365 , 1} $$

# %% [markdown]
# ## Obteniendo por consiguiente:
# ## Recordando que
# $$Q = \frac{1}{2 cos(\psi)}$$ $$T(S) = \frac{1}{S + 1} \frac{1}{S^2 + S 2 cos({\frac{\pi}{5})} + 1} \frac{1}{S^2 + S 2 cos({\frac{3 \pi}{5})} + 1}$$

# %% [markdown]
# ## Elijo $C = 100nF$ y obtengo:
# $$Q_{1} = \frac{1}{2 cos({\frac{\pi}{5})}} = 0,618$$ $$Q_{2} = \frac{1}{2 cos({\frac{3 \pi}{5})}} = 1,618$$
# $$R_{3} =\frac{1}{2 \pi 3200* 10^{-9}} = 4973,6 \Omega$$ $$R_{2_{1}} = Q_{1} R_{3} = 3073,7 \Omega$$ $$R_{2_{2}} = Q_{2} R_{3} = 847,3 \Omega$$
# $$R_{1} = \frac{R_{3}}{|K|} = 24719,68 \Omega$$
# $$R = \frac{1}{2 \pi f_{c}}=4973,6 \Omega$$

# %%
import numpy as np
import matplotlib.pyplot as plt
# %run tarea2.py
# Out:
# $\displaystyle   \frac{1.263 }{s + 1.263 } . \frac{  1 \cdot 1.263^2}{s^2 + s \frac{1.263}{0.618} + 1.263^2} . \frac{0.9999 \cdot 1.263^2}{s^2 + s \frac{1.263}{1.618} + 1.263^2}$
# $\displaystyle   \frac{s \,\,   1 }{s + 0.7915 } . \frac{  1 \cdot s^2}{s^2 + s \frac{0.7915}{0.618} + 0.7915^2} . \frac{0.9999 \cdot s^2}{s^2 + s \frac{0.7915}{1.618} + 0.7915^2}$
# $\displaystyle   \frac{  1 }{s +   1 } . \frac{  1 \cdot   1^2}{s^2 + s \frac{  1}{0.618} +   1^2} . \frac{0.9999 \cdot   1^2}{s^2 + s \frac{  1}{1.618} +   1^2}$
# $\displaystyle \frac{  1 }{s^5 + s^4 \,\, 3.236 + s^3 \,\, 5.236 + s^2 \,\, 5.236 + s \,\, 3.236 +   1 }$
# $\displaystyle   \frac{  1 }{s +   1 } . \frac{  1 \cdot   1^2}{s^2 + s \frac{  1}{0.618} +   1^2} . \frac{0.9999 \cdot   1^2}{s^2 + s \frac{  1}{1.618} +   1^2}$
# Raíces Chebyshev:
# [-0.11932228+1.01949544j -0.11932228-1.01949544j -0.31238979+0.63008283j
#  -0.31238979-0.63008283j -0.38613502+0.j        ]
#
# Numerador:
# [1.]
#
# Denominador:
# ...

# %%
from IPython.display import IFrame

IFrame("Tarea 2.pdf", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="Tarea 2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## la respuesta en modulo y fase del filtro normalizado en ltspice es el siguiente:

# %%
from IPython.display import Image, display

display(Image(filename="moduloYfase_ltspice.jpeg"))

# %% [markdown]
# ## comentario: la frecuencia calculada en la normalizada es $\omega_{0}
