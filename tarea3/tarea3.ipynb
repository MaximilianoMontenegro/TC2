# %% [markdown]
# # Filtro pasabajos Bessel - Montenegro Maximiliano

# %% [markdown]
# # 1-Método Storch para obtener filtros con distintos ordenes, probaremos con n = 2, 3 y 4

# %% [markdown]
# ## método stroch
#
# se parte de l asiguiente ecuación
#
# $$
# T(s) = \frac{1}{senh(\phi) + cosh(\phi)}
# $$
#
# $$
# \frac{cosh(\phi)}{senh(\phi)}
# =
# cotgh(\phi)
# $$
#
# $$
# cotgh(\phi)
# =
# \huge
# \frac{1}{s}+\frac{1}{\frac{3}{s}+\frac{1}{\frac{5}{s}+\cdots}}
# $$

# %% [markdown]
# ## Retardo de grupo
# $$D(2)=-\frac{\partial\phi}{\partial\omega}$$
# $$
# D(\omega)
# =
# -\sum_{i}
# \frac{\theta_i}{\theta_i^2+(\omega - \omega_i)^2}
# +
# \frac{\theta_j}{\theta_j^2+(\omega - \omega_j)^2}
# $$
# $$
# \frac{\omega_0}{Q}=\,B\omega=2\theta_j
# \Rightarrow
# \theta_j=\frac{\,B\omega}{2}
# $$
# $$
# \omega^2=\theta_j^2+\omega_j^2
# \omega_j=\sqrt{\omega^2-\theta_j^2}
# $$

# %% [markdown]
# ## n = 2
# $$
# cotgh(\phi)
# =
# \frac{1}{s}
# +
# \frac{1}{\frac{3}{s}}
# =
# \frac{1}{s}
# +
# \frac{3}{s}
# =
# \frac{s^2+3}{3s}
# =
# \frac{cosh{\phi}}{senh(\phi)}
# $$
#
# $$
# T_2(S)
# =
# \frac{1}{3s + s^2 + 3}
# $$
#
# agregamos el mismo valor que el término independiente en el numerador
#
# $$
# T_2(s) = \frac{3}{s^2 + 3s +3}
# $$
#
# ## n = 3
# $$T_3 = \frac{15}{s^3 + 6s^2 + 15s + 15 }$$
#
# ## n = 4
# $$
# T_4(s)
# =
# \frac{105}{s^4 + 10 s^3 + 45 s^2 + 105 s + 105}
# $$

# %% [markdown]
# a continuacion se procede a encontrar los polos de los siguientes filtros

# %%
# %run tarea3.py
# Out:
# #### Aproximaciones de Bessel
# #### Bessel_ord_2
# $\displaystyle \frac{  3 }{s^2 + s \,\,   3 +   3 }$
# $\displaystyle   \frac{  1 \cdot 1.732^2}{s^2 + s \frac{1.732}{0.5774} + 1.732^2}$
# #### Bessel_ord_3
# $\displaystyle \frac{ 15 }{s^3 + s^2 \,\,   6 + s \,\,  15 +  15 }$
# $\displaystyle   \frac{2.322 }{s + 2.322 } . \frac{  1 \cdot 2.542^2}{s^2 + s \frac{2.542}{0.691} + 2.542^2}$
# #### Bessel_ord_4
# $\displaystyle \frac{105 }{s^4 + s^3 \,\,  10 + s^2 \,\,  45 + s \,\, 105 + 105 }$
# $\displaystyle   \frac{  1 \cdot 3.023^2}{s^2 + s \frac{3.023}{0.5219} + 3.023^2} . \frac{  1 \cdot 3.389^2}{s^2 + s \frac{3.389}{0.8055} + 3.389^2}$

# %% [markdown]
# ## eleccion de transferecnia de menor orden con atenuación de $\alpha$ < 1dB
# ## n = 2
# $$T_2(s=j1)=\frac{3}{(j1)^2 + 3(j1)+3}$$
# $$
# |T_2(s)1
# =
# |\frac{3}{-1+3j+3}|
# =
# \frac{3}{\sqrt{2^2 + 3^2}}
# =
# \frac{3}{sqrt{13}}
# \approx
# 0,832
# $$
# $$
# |T_2(s)|\Big|_{dB}
# =
# 20\log(T_2(s))
# =20\log(0,832)
# \approx
# -1,6\,dB
# $$
# pero como: $$T(s)=1/\alpha(s)$$
# wwntonces:
# $$\alpha_2 \approx 1,6 \,dB$$ No cumple
# ## n =3
# $$
# |T_3(s=j1)|=
# |\frac{2,322}{j1+2,322}\frac{2,542^2}{(j1)^2 + j3,678 + 2,542^2}| \approx 0,901
# $$
# $$
# |T_3(j1)|\big|_{\,dB}
# \approx-0,905 \,dB
# $$
# $$
# \alpha_3 \approx 0,905 \,dB$$Cumple
# $$
# |T_4()j1|=|\frac{3,023^2}{\sqrt{(3,023-1)^2+5,792^2}}
# \frac{3,389^2}{\sqrt{(3,389-1)^2+4,207^2}}|\approx0,930
# $$
# $$
# |T_4(j1)|\big|_{\,dB}
# \approx-0,63 \,dB
# $$
# $$
# \alpha_4 \approx 0,63 \,dB
# $$cumple
# ## cumplen el de orden 3 y 4, pero elegimos el 3 por ser de menor orden

# %% [markdown]
# a continuación se presentara la trasferencia para el orden 3 normalizado y desnormalizado

# %%
from IPython.display import Image, display, Markdown

display(Markdown("### Transferencia normalizada"))
display(Image('transferencia normalizada.png', width=1600))
display(Markdown("se observa la atenuación de la transferencia a los 159mHz de 6 dB "))
display(Markdown("### Transferencia desnormalizada"))
display(Image('transferencia desnormalizada.png', width=1600))
display(Markdown("se observa la atenuación de la transferencia a los 159mHz de 0,9 dB "))
# Out:
# ### Transferencia normalizada
# se observa la atenuación de la transferencia a los 159mHz de 6 dB
# ### Transferencia desnormalizada
# se observa la atenuación de la transferencia a los 159mHz de 0,9 dB

# %% [markdown]
# ## Retardo de grupo
# Para la resolución de siguieten ejercicio, se utilizó la transferecnia de orden n = 3
# $$
# D_3(\omega)=\sum_{j}\frac{\theta_j}{\theta_j^2 + (\omega - \omega_j)^2}
# $$
# $$
# \omega_0 = 2,542
# \qquad\qquad
# \,Q = 0,691
# \qquad\qquad
# \,B\omega=\frac{\omega_0}{Q}
# $$
# $$
# \,B\omega=3,678
# \qquad\qquad
# \Rightarrow
# \qquad\qquad
# \theta=\frac{\,B\omega}{2}=1,839
# \approx 1,755
# $$
# $$
# \omega_j=\sqrt{\omega_0^2-\theta_j^2}
# \qquad\qquad
# \sqrt{2,542^2-1,839^2}
# $$
# $$
# D_3(\omega)=\frac{2,322}{2,322+\omega^2}
# +
# \frac{1,839}{1,839^2+(\omega-1,755)^2}
# +
# \frac{1,839}{1,839^2+(\omega+1,755)^2}
# $$
# $$
# D_3(\omega=2,5)=\frac{2,322}{2,322+2,5^2}
# +
# \frac{1,839}{1,839^2+(2,5-1,755)^2}
# +
# \frac{1,839}{1,839^2+(2,5+1,755)^2}
# \approx 0,7235
# $$
# el error porcentual es:
# $$
# \,E\%=\frac{D(0)-D{2,5}}{D(0)}100\%
# \qquad\qquad
# \frac{1-0,7525}{1}100\%=24,25\%
# $$

# %%
from IPython.display import Image, display, Markdown

display(Markdown("### Retardo de gruupo"))
display(Image('retardo.png', width=1600))
display(Markdown("se observa el el cuadro que al posicionarnos en la frecuencia de aproximada mente 387 ms se dal el retado esperado"))
display(Markdown("el tiempo elegido, es resultadode realizar la división entre 2,5 y 2pi"))
# Out:
# ### Retardo de gruupo
# se observa el el cuadro que al posicionarnos en la frecuencia de aproximada mente 387 ms se dal el retado esperado
# el tiempo elegido, es resultadode realizar la división entre 2,5 y 2pi

# %%
from IPython.display import IFrame

IFrame("Tarea3.pdf",width=800, height=1000)
# Out:
#         <iframe
#             width="800"
#             height="1000"
#             src="Tarea3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
