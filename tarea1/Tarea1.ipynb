# %% [markdown]
# # Tarea 1 - Fitro pasabandas - Montenegro Maximiliano

# %% [markdown]
# la transferencia es: $$H(s)=A\frac{s}{s^2+sQ+\omega_0^2}$$

# %% [markdown]
# siendo: $$A = \frac{R_4+R_5}{R\,R_5\,C}$$
# $$Q = \frac{1}{R\,C}$$ $$\omega_0^2 = \frac{R_49}{R_1\,R_3\,R_5\,C_2\,C}$$

# %% [markdown]
# los valores obtenidos son: $$R = 6777,5 \Omega$$ $$R_1 = R_3 = 6964,54 \Omega$$ $$R_4 = 9K\Omega$$
# $$R_5 = 1K\Omega$$ $$C = 47 nF$$ $$C_2 = 1 nF$$

# %% [markdown]
# ### Acontinuación, se procede a plotear como queda la respuesta en frecuencia (bode y lineal), la respues en fase y el diagrama de polos y ceros.

# %% [markdown]
# ### lo curioso, es que en el programa LTSpice, la amplitud no me estari dando igual que la respuesta mostrada a continuación, en el programa Tina si me da el resultado esperado

# %%
# %run tarea1.py
# Out:
# Ceros: [0.]
# Polos: [-1570.80810223+62902.59243573j -1570.80810223-62902.59243573j]
# Ganancia: 31416.16204456383

# %% [markdown]
# # Resolución manuscrita

# %%
from IPython.display import IFrame

IFrame("Tarea 1_Montenegro.pdf",width=900,height=700)
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="Tarea 1_Montenegro.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
