# %% [markdown]
# # Tarea 6 - Montenegro Maximiliano

# %%
import sys
print(sys.executable)
# Out:
# /home/monezemax/.espressif/python_env/idf5.4_py3.10_env/bin/python

# %%
# %cd "/home/monezemax/UTN/CuartoAnio/Teoria de los circuitos 2/TC2/tarea6/Python_Spyder"
# Out:
# /home/monezemax/UTN/CuartoAnio/Teoria de los circuitos 2/TC2/tarea6/Python_Spyder

# %%
# %run tarea_6.py
# Out:
# ciruito tee
# Mosfet
# #### Matriz Admitancia Indefinida:
# $$$Y_MAI=\left[\begin{matrix}\frac{C L s^{2} + 1}{L s \left(C L s^{2} + 2\right)} & - \frac{1}{L s \left(C L s^{2} + 2\right)} & - \frac{C s}{C L s^{2} + 2}\\- \frac{1}{L s \left(C L s^{2} + 2\right)} & \frac{C L s^{2} + 1}{L s \left(C L s^{2} + 2\right)} & - \frac{C s}{C L s^{2} + 2}\\- \frac{C s}{C L s^{2} + 2} & - \frac{C s}{C L s^{2} + 2} & \frac{2 C s}{C L s^{2} + 2}\end{matrix}\right]$$$
# #### Matriz Admitancia Indefinida del MOSFET:
# $$$Y_{MAI}=\left[\begin{matrix}s \left(C_{gd} + C_{gs}\right) & - C_{gd} s & - C_{gs} s\\- C_{gd} s + g_{m} & s \left(C_{ds} + C_{gd}\right) & - C_{ds} s - g_{m}\\- C_{gs} s - g_{m} & - C_{ds} s & g_{m} + s \left(C_{ds} + C_{gs}\right)\end{matrix}\right]$$$
# Obtengo las transferencias:
# $$\frac{V_{23}}{V_{13}} = \frac{1}{C L s^{2} + 1}$$
# $$\frac{V_{21}}{V_{31}} = \frac{C L s^{2}}{C L s^{2} + 1}$$
# $$\frac{V_{12}}{V_{32}} = \frac{C L s^{2}}{C L s^{2} + 1}$$
# ...

# %% [markdown]
# ## Admitancias obtenidas con LTSpice

# %% [markdown]
# ### Medición de los parámetros Y
#
# #### $Y_{11}$
# ![Y11](imagenes/Y11.png)
#
# #### $Y_{12}$
# ![Y12](imagenes/Y12.png)
#
# #### $Y_{21}$
# ![Y21](imagenes/Y21.png)
#
# #### $Y_{22}$
# ![Y22](imagenes/Y22.png)

# %% [markdown]
# # PDM con ejercicio desarrollado a mano

# %%
from IPython.display import IFrame

IFrame("../manuscrito/Tarea 6_260817_232241.pdf", width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="../manuscrito/Tarea 6_260817_232241.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
